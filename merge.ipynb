# %%
import pandas as pd
import glob

# Path to extracted CSVs
path = "CICIDS2017/"   # folder in same directory as notebook
files = glob.glob(path + "*.csv")

print("Files found:", len(files))
files
# Out:
# Files found: 0
# []
